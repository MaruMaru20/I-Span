-- %% [markdown]
-- # [AddressBook]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AddressBook]    Script Date: 2024/12/3 下午 12:47:51 ******/
CREATE DATABASE [AddressBook]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AddressBook', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\AddressBook.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AddressBook_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\AddressBook_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [AddressBook] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AddressBook].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AddressBook] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AddressBook] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AddressBook] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AddressBook] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AddressBook] SET ARITHABORT OFF 
GO
ALTER DATABASE [AddressBook] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [AddressBook] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AddressBook] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AddressBook] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AddressBook] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AddressBook] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AddressBook] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AddressBook] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AddressBook] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AddressBook] SET  ENABLE_BROKER 
GO
ALTER DATABASE [AddressBook] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AddressBook] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AddressBook] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AddressBook] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AddressBook] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AddressBook] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AddressBook] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AddressBook] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [AddressBook] SET  MULTI_USER 
GO
ALTER DATABASE [AddressBook] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AddressBook] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AddressBook] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AddressBook] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AddressBook] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AddressBook] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [AddressBook] SET QUERY_STORE = ON
GO
ALTER DATABASE [AddressBook] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[House]

-- %%
USE [AddressBook]
GO

-- %%
/****** Object:  Table [dbo].[House]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[House](
	[hid] [int] NOT NULL,
	[address] [nvarchar](100) NULL,
 CONSTRAINT [PK_House] PRIMARY KEY CLUSTERED 
(
	[hid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Live]

-- %%
/****** Object:  Table [dbo].[Live]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Live](
	[uid] [nvarchar](20) NOT NULL,
	[hid] [int] NOT NULL,
 CONSTRAINT [PK_Live] PRIMARY KEY CLUSTERED 
(
	[uid] ASC,
	[hid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vw_vacancy_rate]

-- %%
/****** Object:  View [dbo].[vw_vacancy_rate]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create view [dbo].[vw_vacancy_rate] as
select concat (round((
	select count(*) as '空屋'
	from House left join live
		on House.hid = live.hid
	where uid is null
)
/cast((select count(*)  from house) as float), 3)* 100, '%') as 'rate'
GO

-- %% [markdown]
-- # [dbo].[Bill]

-- %%
/****** Object:  Table [dbo].[Bill]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bill](
	[tel] [nvarchar](20) NOT NULL,
	[fee] [int] NULL,
	[hid] [int] NULL,
	[dd] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_Bill] PRIMARY KEY CLUSTERED 
(
	[tel] ASC,
	[dd] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HeadPhoto]

-- %%
/****** Object:  Table [dbo].[HeadPhoto]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HeadPhoto](
	[uid] [nvarchar](20) NOT NULL,
	[photo] [varbinary](max) NULL,
 CONSTRAINT [PK_HeadPhoto] PRIMARY KEY CLUSTERED 
(
	[uid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Log]

-- %%
/****** Object:  Table [dbo].[Log]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Log](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[body] [nvarchar](200) NULL,
	[dd] [datetime2](7) NULL,
 CONSTRAINT [PK_Log] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Phone]

-- %%
/****** Object:  Table [dbo].[Phone]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Phone](
	[tel] [nvarchar](20) NOT NULL,
	[hid] [int] NULL,
 CONSTRAINT [PK_Phone] PRIMARY KEY CLUSTERED 
(
	[tel] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserInfo]

-- %%
/****** Object:  Table [dbo].[UserInfo]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserInfo](
	[uid] [nvarchar](20) NOT NULL,
	[cname] [nvarchar](51) NULL,
	[password] [nvarchar](40) NULL,
	[birthday] [datetime2](7) NULL,
	[isdeleted] [tinyint] NULL,
	[deletedat] [datetime2](7) NULL,
 CONSTRAINT [PK_UserInfo] PRIMARY KEY CLUSTERED 
(
	[uid] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bill]

-- %%
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1111', 300, 1, CAST(N'2019-01-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1111', 700, 1, CAST(N'2019-02-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1111', 900, 1, CAST(N'2019-11-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1111', 2000, 1, CAST(N'2024-12-02T15:23:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1112', 700, 1, CAST(N'2019-01-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1112', 450, 1, CAST(N'2019-02-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'1112', 200, 1, CAST(N'2019-03-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'2222', 150, 2, CAST(N'2019-01-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'2222', 400, 2, CAST(N'2019-02-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'2222', 300, 2, CAST(N'2019-03-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'3333', 500, 3, CAST(N'2019-04-01T00:00:00.0000000' AS DateTime2))
INSERT [dbo].[Bill] ([tel], [fee], [hid], [dd]) VALUES (N'3333', 350, 3, CAST(N'2019-10-01T00:00:00.0000000' AS DateTime2))
GO

-- %% [markdown]
-- # [dbo].[HeadPhoto]

-- %%
INSERT [dbo].[HeadPhoto] ([uid], [photo]) VALUES (N'A01', ...)
GO

-- %% [markdown]
-- # [dbo].[House]

-- %%
INSERT [dbo].[House] ([hid], [address]) VALUES (1, N'台北市南京東路1號')
INSERT [dbo].[House] ([hid], [address]) VALUES (2, N'新竹市光復北路1號')
INSERT [dbo].[House] ([hid], [address]) VALUES (3, N'台中市公益路二段51號')
INSERT [dbo].[House] ([hid], [address]) VALUES (4, N'高雄市五福路3號')
INSERT [dbo].[House] ([hid], [address]) VALUES (5, N'花蓮')
INSERT [dbo].[House] ([hid], [address]) VALUES (6, N'移狼')
GO

-- %% [markdown]
-- # [dbo].[Live]

-- %%
INSERT [dbo].[Live] ([uid], [hid]) VALUES (N'A01', 1)
INSERT [dbo].[Live] ([uid], [hid]) VALUES (N'A01', 3)
INSERT [dbo].[Live] ([uid], [hid]) VALUES (N'A02', 1)
INSERT [dbo].[Live] ([uid], [hid]) VALUES (N'A03', 1)
GO

-- %% [markdown]
-- # [dbo].[Log]

-- %%
SET IDENTITY_INSERT [dbo].[Log] ON 
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (1, N'在userinfo資料表中插入C01, David的資料', CAST(N'2024-12-03T09:18:08.4533333' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (2, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:17:46.1800000' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (3, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:17:47.5066667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (4, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:17:51.0166667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (5, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:17:58.3066667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (6, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:18:02.3366667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (7, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:18:14.4666667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (14, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:23:51.3233333' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (15, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:28:45.7333333' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (16, N'在 userinfo 資料表中更新了資料：原資料 -> (A01, 王大明), 新資料 -> (A01, 王大明)', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2))
INSERT [dbo].[Log] ([id], [body], [dd]) VALUES (18, N'在 userinfo 資料表中更新了資料：原資料 -> (C01, David), 新資料 -> (C01, David)', CAST(N'2024-12-03T10:45:33.5633333' AS DateTime2))
SET IDENTITY_INSERT [dbo].[Log] OFF
GO

-- %% [markdown]
-- # [dbo].[Phone]

-- %%
INSERT [dbo].[Phone] ([tel], [hid]) VALUES (N'1111', 1)
INSERT [dbo].[Phone] ([tel], [hid]) VALUES (N'1112', 1)
INSERT [dbo].[Phone] ([tel], [hid]) VALUES (N'2222', 2)
INSERT [dbo].[Phone] ([tel], [hid]) VALUES (N'3333', 3)
GO

-- %% [markdown]
-- # [dbo].[UserInfo]

-- %%
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A01', N'王大明', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A02', N'李大媽', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A03', N'王小毛', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A04', N'朱小妹', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A05', NULL, N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'A06', N'', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), NULL, NULL)
INSERT [dbo].[UserInfo] ([uid], [cname], [password], [birthday], [isdeleted], [deletedat]) VALUES (N'C01', N'David', N'12346', CAST(N'2024-12-03T10:28:48.0666667' AS DateTime2), 1, CAST(N'2024-12-03T10:45:33.5633333' AS DateTime2))
GO

-- %% [markdown]
-- # [DF_Bill_dd]

-- %%
ALTER TABLE [dbo].[Bill] ADD  CONSTRAINT [DF_Bill_dd]  DEFAULT (getdate()) FOR [dd]
GO

-- %% [markdown]
-- # [DEFAULT_Log_dd]

-- %%
ALTER TABLE [dbo].[Log] ADD  CONSTRAINT [DEFAULT_Log_dd]  DEFAULT (getdate()) FOR [dd]
GO

-- %% [markdown]
-- # [FK_Bill_House]

-- %%
ALTER TABLE [dbo].[Bill]  WITH CHECK ADD  CONSTRAINT [FK_Bill_House] FOREIGN KEY([hid])
REFERENCES [dbo].[House] ([hid])
GO
ALTER TABLE [dbo].[Bill] CHECK CONSTRAINT [FK_Bill_House]
GO

-- %% [markdown]
-- # [FK_Bill_Phone]

-- %%
ALTER TABLE [dbo].[Bill]  WITH CHECK ADD  CONSTRAINT [FK_Bill_Phone] FOREIGN KEY([tel])
REFERENCES [dbo].[Phone] ([tel])
GO
ALTER TABLE [dbo].[Bill] CHECK CONSTRAINT [FK_Bill_Phone]
GO

-- %% [markdown]
-- # [FK_HeadPhoto_UserInfo]

-- %%
ALTER TABLE [dbo].[HeadPhoto]  WITH CHECK ADD  CONSTRAINT [FK_HeadPhoto_UserInfo] FOREIGN KEY([uid])
REFERENCES [dbo].[UserInfo] ([uid])
GO
ALTER TABLE [dbo].[HeadPhoto] CHECK CONSTRAINT [FK_HeadPhoto_UserInfo]
GO

-- %% [markdown]
-- # [FK_Live_House]

-- %%
ALTER TABLE [dbo].[Live]  WITH CHECK ADD  CONSTRAINT [FK_Live_House] FOREIGN KEY([hid])
REFERENCES [dbo].[House] ([hid])
GO
ALTER TABLE [dbo].[Live] CHECK CONSTRAINT [FK_Live_House]
GO

-- %% [markdown]
-- # [FK_Live_UserInfo]

-- %%
ALTER TABLE [dbo].[Live]  WITH CHECK ADD  CONSTRAINT [FK_Live_UserInfo] FOREIGN KEY([uid])
REFERENCES [dbo].[UserInfo] ([uid])
GO
ALTER TABLE [dbo].[Live] CHECK CONSTRAINT [FK_Live_UserInfo]
GO

-- %% [markdown]
-- # [FK_Phone_House]

-- %%
ALTER TABLE [dbo].[Phone]  WITH CHECK ADD  CONSTRAINT [FK_Phone_House] FOREIGN KEY([hid])
REFERENCES [dbo].[House] ([hid])
GO
ALTER TABLE [dbo].[Phone] CHECK CONSTRAINT [FK_Phone_House]
GO

-- %% [markdown]
-- # [dbo].[login]

-- %%
/****** Object:  StoredProcedure [dbo].[login]    Script Date: 2024/12/3 下午 12:47:51 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[login]
	@uid nvarchar(50),
	@pwd nvarchar(50)
as
begin
	declare @isok tinyint = 0
	select @isok = count(*) from userinfo where uid = @uid and password =@pwd
	select @isok as 'status'
end
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'帳單地址' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Bill', @level2type=N'COLUMN',@level2name=N'hid'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'帳號' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'HeadPhoto', @level2type=N'COLUMN',@level2name=N'uid'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'大頭照' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'HeadPhoto', @level2type=N'COLUMN',@level2name=N'photo'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'自動編號' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Log', @level2type=N'COLUMN',@level2name=N'id'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'有預設時間' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Log', @level2type=N'COLUMN',@level2name=N'dd'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'家用電話' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Phone', @level2type=N'COLUMN',@level2name=N'tel'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'裝機地址' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'Phone', @level2type=N'COLUMN',@level2name=N'hid'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'帳號' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'UserInfo', @level2type=N'COLUMN',@level2name=N'uid'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'中文姓名' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'UserInfo', @level2type=N'COLUMN',@level2name=N'cname'
GO

-- %% [markdown]
-- # [MS_Description]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_Description', @value=N'密碼（記得加密）' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'TABLE',@level1name=N'UserInfo', @level2type=N'COLUMN',@level2name=N'password'
GO

-- %% [markdown]
-- # [AddressBook]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AddressBook] SET  READ_WRITE 
GO
